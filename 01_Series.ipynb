# %%
import pandas as pd
import numpy as np

# %%
arr = np.array([12,13,14,15,16,17])
arr
# Out:
# array([12, 13, 14, 15, 16, 17])

# %%
print(pd.__version__) # for checking the version of pandas
# Out:
# 3.0.3

# %%
# series in pandas
marks = pd.Series([90,89,76,87,78,98])
marks
# Out:
# 0    90
# 1    89
# 2    76
# 3    87
# 4    78
# 5    98
# dtype: int64

# %%
# accessing series element
print(marks[4])

# we can also slicing the element of series
print(marks[1:4])
# Out:
# 78
# 1    89
# 2    76
# 3    87
# dtype: int64

# %%
# creating your own index
detail = pd.Series(
    [89,56,78],
    index = ["Shiva","Alice","Bob"]
)
print(detail)

print(detail["Shiva"])
# Out:
# Shiva    89
# Alice    56
# Bob      78
# dtype: int64
# 89
