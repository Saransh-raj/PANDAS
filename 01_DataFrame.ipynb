# %%
import pandas as pd

# %%
data = {
    "Name" : ["Saransh","Humera","Abhi"],
    "Age" : [20,21,23],
    "Marks" : [78,100,65]
}

pd.DataFrame(data)
# Out:
#       Name  Age  Marks
# 0  Saransh   20     78
# 1   Humera   21    100
# 2     Abhi   23     65
